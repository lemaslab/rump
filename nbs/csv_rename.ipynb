# %%
import pandas as pd
import csv

# %%
data = pd.read_csv("../results/lemas_mzmine_localrun/Lemas_POS_mzmine_Local_run.csv", dtype = str, quoting = csv.QUOTE_ALL)

# %%
data.head()
# Out:
#   row ID             row m/z  row retention time  \
# 0   1998  127.03922225952148  0.7873600000000001
# 1   1990  145.04959716796876            0.794602
# 2   2020  184.07342429783034  0.7323731884057972
# 3   3613  117.05500030517578  0.7693126666666665
# 4   3609   258.1097751969286  0.7606212121212121
#
#           row identity (main ID)  \
# 0  5-Hydroxymethyl-2-furaldehyde
# 1            2,3-Dimethylmaleate
# 2                 PHOSPHOCHOLINE
# 3            5-Oxopentanoic acid
# 4          Glycerophosphocholine
#
#                               row identity (all IDs)  \
# 0  5-Hydroxymethyl-2-furaldehyde;1,2,3-Trihydroxy...
# 1  2,3-Dimethylmaleate;Triacetate;Methylitaconate...
# 2  PHOSPHOCHOLINE;4-Amino-2-hydroxylamino-6-nitro...
# 3  5-Oxopentanoic acid;3-Methyl-2-oxobutanoic aci...
# 4                              Glycerophosphocholine
#
#                     row identity (main ID + details) row comment  \
# 0  ID: 237332p;Name: 5-Hydroxymethyl-2-furaldehyd...         NaN
# ...

# %%
selected_columns = ["row ID", "row m/z", "row retention time", "row identity (main ID)", "row identity (all IDs)", 
                    "row identity (main ID + details)", "row comment", "1[Blank]p.mzXML Peak height", "2[Blank]p.mzXML Peak height", 
                    "3[Blank]p.mzXML Peak height", "4[Blank]p.mzXML Peak height", "1[extBlank]p.mzXML Peak height", 
                    "2[extBlank]p.mzXML Peak height", "3[extBlank]p.mzXML Peak height", "4[extBlank]p.mzXML Peak height", 
                    "1[NeatQC]p.mzXML Peak height", "2[NeatQC]p.mzXML Peak height", "1[BLS001A]p.mzXML Peak height", 
                    "10[BLS010A]p.mzXML Peak height", 
                    "11[BLS010A]p.mzXML Peak height", "12[BLS010A]p.mzXML Peak height", "2[BLS001A]p.mzXML Peak height", 
                    "4[BLS002A]p.mzXML Peak height", "7[BLS003A]p.mzXML Peak height", "3[BLS001A]p.mzXML Peak height", 
                    "5[BLS002A]p.mzXML Peak height", "8[BLS003A]p.mzXML Peak height", "9[BLS003A]p.mzXML Peak height", 
                    "6[BLS002A]p.mzXML Peak height", "1[BLS001A]p-dd.mzXML Peak height", "2[BLS001A]p-dd.mzXML Peak height", 
                    "3[BLS001A]p-dd.mzXML Peak height"]

# %%
data_selected = data[selected_columns]

# %%
data_selected = data_selected.rename(index=str, columns={"row ID": "row.ID", 
                                                         "row m/z": "row.m.z",
                                                         "row retention time": "row.retention.time", 
                                                         "row identity (main ID)": "row.identity.main.ID", 
                                                         "row identity (all IDs)": "row.identity.all.IDs", 
                                                         "row identity (main ID + details)": "row.identity.main ID.details", 
                                                         "row comment": "row.comment", 
                                                         "1[Blank]p.mzXML Peak height": "X1.Blank.p.mzXML.Peak.height", 
                                                         "2[Blank]p.mzXML Peak height": "X2.Blank.p.mzXML.Peak.height", 
                                                         "3[Blank]p.mzXML Peak height": "X3.Blank.p.mzXML.Peak.height", 
                                                         "4[Blank]p.mzXML Peak height": "X4.Blank.p.mzXML.Peak.height", 
                                                         "1[extBlank]p.mzXML Peak height": "X1.extBlank.p.mzXML.Peak.height", 
                                                         "2[extBlank]p.mzXML Peak height": "X2.extBlank.p.mzXML.Peak.height", 
                                                         "3[extBlank]p.mzXML Peak height": "X3.extBlank.p.mzXML.Peak.height", 
                                                         "4[extBlank]p.mzXML Peak height": "X4.extBlank.p.mzXML.Peak.height", 
                                                         "1[NeatQC]p.mzXML Peak height": "X1.NeatQC.p.mzXML.Peak.height", 
                                                         "2[NeatQC]p.mzXML Peak height": "X2.NeatQC.p.mzXML.Peak.height", 
                                                         "1[NeatQC]p.mzXML Peak height": "X1.NeatQC.p.mzXML.Peak.height", 
                                                         "1[BLS001A]p.mzXML Peak height": "X1.BLS001A.p.mzXML.Peak.height", 
                                                         "10[BLS010A]p.mzXML Peak height": "X10.BLS010A.p.mzXML.Peak.height", 
                                                         "11[BLS010A]p.mzXML Peak height": "X11.BLS010A.p.mzXML.Peak.height",
                                                         "12[BLS010A]p.mzXML Peak height": "X12.BLS010A.p.mzXML.Peak.height", 
                                                         "2[BLS001A]p.mzXML Peak height": "X2.BLS001A.p.mzXML.Peak.height", 
                                                         "4[BLS002A]p.mzXML Peak height": "X4.BLS002A.p.mzXML.Peak.height", 
                                                         "7[BLS003A]p.mzXML Peak height": "X7.BLS003A.p.mzXML.Peak.height", 
                                                         "3[BLS001A]p.mzXML Peak height": "X3.BLS001A.p.mzXML.Peak.height", 
                                                         "5[BLS002A]p.mzXML Peak height": "X5.BLS002A.p.mzXML.Peak.height", 
                                                         "8[BLS003A]p.mzXML Peak height": "X8.BLS003A.p.mzXML.Peak.height", 
                                                         "9[BLS003A]p.mzXML Peak height": "X9.BLS003A.p.mzXML.Peak.height", 
                                                         "6[BLS002A]p.mzXML Peak height": "X6.BLS002A.p.mzXML.Peak.height", 
                                                         "1[BLS001A]p-dd.mzXML Peak height": "X1.BLS001A.p.dd.mzXML.Peak.height", 
                                                         "2[BLS001A]p-dd.mzXML Peak height": "X2.BLS001A.p.dd.mzXML.Peak.height", 
                                                         "3[BLS001A]p-dd.mzXML Peak height": "X3.BLS001A.p.dd.mzXML.Peak.height"})

# %%
data_selected.head()
# Out:
#   row.ID             row.m.z  row.retention.time  \
# 0   1998  127.03922225952148  0.7873600000000001
# 1   1990  145.04959716796876            0.794602
# 2   2020  184.07342429783034  0.7323731884057972
# 3   3613  117.05500030517578  0.7693126666666665
# 4   3609   258.1097751969286  0.7606212121212121
#
#             row.identity.main.ID  \
# 0  5-Hydroxymethyl-2-furaldehyde
# 1            2,3-Dimethylmaleate
# 2                 PHOSPHOCHOLINE
# 3            5-Oxopentanoic acid
# 4          Glycerophosphocholine
#
#                                 row.identity.all.IDs  \
# 0  5-Hydroxymethyl-2-furaldehyde;1,2,3-Trihydroxy...
# 1  2,3-Dimethylmaleate;Triacetate;Methylitaconate...
# 2  PHOSPHOCHOLINE;4-Amino-2-hydroxylamino-6-nitro...
# 3  5-Oxopentanoic acid;3-Methyl-2-oxobutanoic aci...
# 4                              Glycerophosphocholine
#
#                         row.identity.main ID.details row.comment  \
# 0  ID: 237332p;Name: 5-Hydroxymethyl-2-furaldehyd...         NaN
# ...

# %%
data_selected.to_csv("../results/lemas_mzmine_localrun/Lemas_POS_mzmine_Local_run_modified.csv", index = False)
